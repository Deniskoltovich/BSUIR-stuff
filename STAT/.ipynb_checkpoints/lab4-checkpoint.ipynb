# %%
import sklearn
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
PATH = "Credit Score Classification Dataset.csv"
dataset = pd.read_csv(PATH)
X_numerical = ['Income', 'Number of Children', 'Age']
X_categorical  = ['Gender', 'Education', 'Marital Status', 'Home Ownership', 'Credit Score']

label_encoder = LabelEncoder()
for cat in X_categorical:
    dataset[cat] = label_encoder.fit_transform(dataset[cat])
scaler = StandardScaler()

dataset[X_numerical] = scaler.fit_transform(dataset[X_numerical])

dataset
# Out:
#           Age  Gender    Income  Education  Marital Status  \
# 0   -1.535320       0 -1.043483          1               1
# 1   -0.943702       1  0.501720          4               0
# 2   -0.352085       0 -0.270882          2               0
# 3    0.239533       1  1.274322          3               1
# 4    0.831151       0  0.501720          1               0
# ..        ...     ...       ...        ...             ...
# 159 -1.062026       0 -1.738825          3               1
# 160 -0.470408       1 -1.120744          0               1
# 161  0.121209       0 -0.657183          1               0
# 162  0.712827       1  0.115419          4               1
# 163  1.304445       0 -0.193622          2               0
#
#      Number of Children  Home Ownership  Credit Score
# 0             -0.740862               1             1
# 1              1.530191               0             1
# 2              0.394665               0             1
# 3             -0.740862               0             1
# 4              2.665717               0             1
# ..                  ...             ...           ...
# 159           -0.740862               1             2
# 160           -0.740862               1             0
# 161            1.530191               0             1
# 162           -0.740862               0             1
# 163            0.394665               0             1
#
# [164 rows x 8 columns]

# %%
sns.heatmap(
    round(abs(dataset.corr()),1,),
    annot=True
)
# Out:
# <Axes: >

# %%
train_input, test_input, train_output, test_output = train_test_split(
    dataset.drop("Credit Score", axis=1),
    dataset["Credit Score"],
    test_size=0.2
)

# %%
model = tree.DecisionTreeClassifier()
model.fit(train_input, train_output)
predictions = model.predict(test_input)
confusion_matrix = sklearn.metrics.confusion_matrix(predictions, test_output)
sns.heatmap(
confusion_matrix,
annot=True
)
plt.title('Матрица сходства')
# Out:
# Text(0.5, 1.0, 'Матрица сходства')

# %%
DPI = 450
plt.figure(dpi=DPI)
tree.plot_tree(model)
plt.title("Дерево решений")
# Out:
# Text(0.5, 1.0, 'Дерево решений')
